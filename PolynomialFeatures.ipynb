# %% [markdown]
# **POLYNOMIAL REGRESSION**

# %% [raw]
# Polynomial Regression is an extension of Linear Regression that fits a non-linear curve to the data by adding higher-degree terms

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error,r2_score

# %%
df=pd.read_csv('emp.csv')

# %%
df['Gender'] = df['Gender'].map({'Male': 1, 'Female': 0})
print(df.head())
# Out:
#    ID     Name  Age  Gender       City  Salary Joining_Date
# 0   1    Alice   25       0     Mumbai   50000   2020-01-15
# 1   2      Bob   30       1      Delhi   60000   2019-03-20
# 2   3  Charlie   22       1  Bangalore   45000   2021-07-10
# 3   4    David   28       1  Hyderabad   70000   2018-11-25
# 4   5      Eva   35       0    Chennai   55000   2022-05-30

# %%
X=df[['Gender']]
y=df['Salary']

# %%
poly=PolynomialFeatures(degree=2)
X_poly=poly.fit_transform(X)
model=LinearRegression()
model.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_poly)
print("MSE:", mean_squared_error(y,y_pred))
print("R**2 Score:",r2_score(y,y_pred))
# Out:
# MSE: 63918888.88888889
# R**2 Score: 0.026405865901696135

# %%
plt.scatter(X, y, color='brown', label='Actual')
plt.scatter(X, y_pred, color='green', label='Predicted')
plt.xlabel('Gender (1 = Male, 0 = Female)')
plt.ylabel('Salary')
plt.title('Gender vs Salary Regression')
plt.legend()
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 git --version
#
# NameError: name 'git' is not defined
